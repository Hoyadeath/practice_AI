# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoyadeath/practice_AI/blob/main/P_5_Scaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 0. Load ibarary and data

# %%
from google.colab import files
hr_data_preprocessing = files.upload()
# Out:
#      <input type="file" id="files-7171fe1b-036f-47bc-b39d-fac013e24160" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7171fe1b-036f-47bc-b39d-fac013e24160">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
import sklearn

# %%
print("library version check")
print("pandas:", pd.__version__)
print("sklearn:", sklearn.__version__)
# Out:
# library version check
# pandas: 1.5.3
# sklearn: 1.2.2

# %%
df = pd.read_csv("../content/hr_data_preprocessing.csv", encoding="utf-8", index_col=0)

# %% [markdown]
# ## 1. Separate train and test data

# %%
features = ["job_satisfaction",
            "working_hours",
            "num_companies_worked",
            "age",
            "years_at_company",
            "salary_increasing_rate",
            "department_hr",
            "department_rnd",
            "department_sales",
            "marital_status_etc",
            "marital_status_married",
            "marital_status_single"
            ]

# %%
x_data = df[features]
y_data = df["attrition"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data,
                                                    test_size=0.25,
                                                    random_state=42,
                                                    stratify=y_data)
#1. Never use test data for training or other purposes, even for scaling
#2. Separate train and test data before scaling

# %%
print("test데이터의 비율:", len(y_test)/len(df))
# Out:
# test데이터의 비율: 0.25017135023989034

# %%
x_train.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-ad43a8349319> in <cell line: 1>()
# ----> 1 x_train.index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
train_indx = x_train.index
test_indx = x_test.index

# %%
print("전체 데이터의 퇴직자 비율:", y_data.sum()/len(df))
print("test 데이터의 퇴직자 수:", y_test.sum())
print("test 데이터의 퇴직자 비율:", y_test.sum()/len(y_test))
# Out:
# 전체 데이터의 퇴직자 비율: 0.16038382453735436
# test 데이터의 퇴직자 수: 59
# test 데이터의 퇴직자 비율: 0.16164383561643836

# %% [markdown]
# ##2. Data scaling

# %%
#from sklearn.preprocessing = MinMaxSclaer, StandardScaler, RobustScaler
minmax_scaler = MinMaxScaler()
x_train = minmax_scaler.fit_transform(x_train)

# %%
x_train_scaled = pd.DataFrame(x_train, columns=features, index=train_indx)

# %%
x_train_scaled
# Out:
#       job_satisfaction  working_hours  num_companies_worked       age  \
# 1274          1.000000       0.356223              0.111111  0.309524
# 1080          0.333333       0.858369              0.888889  0.666667
# 1387          0.000000       0.484979              0.000000  0.261905
# 971           0.333333       0.227468              0.333333  0.785714
# 62            0.666667       0.613734              0.555556  0.761905
# ...                ...            ...                   ...       ...
# 364           0.000000       0.712446              0.666667  0.452381
# 192           0.666667       0.111588              0.333333  0.404762
# 1014          0.333333       0.484979              0.222222  0.309524
# 1284          0.666667       0.111588              0.777778  0.500000
# 370           0.333333       0.613734              0.111111  0.071429
#
#       years_at_company  salary_increasing_rate  department_hr  department_rnd  \
# ...

# %%
# No fit. for x_test
x_test = minmax_scaler.transform(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(

# %%
x_test_scaled = pd.DataFrame(x_test, columns=features, index=test_indx)

# %%
train = x_train_scaled.merge(y_train, left_index=True, right_index=True)
test = x_test_scaled.merge(y_test, left_index=True, right_index=True)

# %%
train.to_csv("../content/hr_train_scaling.csv", encoding="utf-8")
test.to_csv("../content/hr_test_scaling.csv", encoding="utf-8")

# %%
train
# Out:
#       job_satisfaction  working_hours  num_companies_worked       age  \
# 1274          1.000000       0.356223              0.111111  0.309524
# 1080          0.333333       0.858369              0.888889  0.666667
# 1387          0.000000       0.484979              0.000000  0.261905
# 971           0.333333       0.227468              0.333333  0.785714
# 62            0.666667       0.613734              0.555556  0.761905
# ...                ...            ...                   ...       ...
# 364           0.000000       0.712446              0.666667  0.452381
# 192           0.666667       0.111588              0.333333  0.404762
# 1014          0.333333       0.484979              0.222222  0.309524
# 1284          0.666667       0.111588              0.777778  0.500000
# 370           0.333333       0.613734              0.111111  0.071429
#
#       years_at_company  salary_increasing_rate  department_hr  department_rnd  \
# ...

# %%
test
# Out:
#       job_satisfaction  working_hours  num_companies_worked   age  \
# 929                3.0           8.10                   2.0  32.0
# 1446               2.0           6.93                   1.0  38.0
# 898                3.0           7.50                   3.0  47.0
# 1068               0.0           7.80                   7.0  32.0
# 827                2.0           8.10                   1.0  32.0
# ...                ...            ...                   ...   ...
# 1218               2.0           9.00                   1.0  45.0
# 53                 0.0           7.20                   2.0  39.0
# 1176               1.0           8.67                   3.0  53.0
# 1394               3.0           7.80                   8.0  36.0
# 655                1.0           7.80                   3.0  37.0
#
#       years_at_company  salary_increasing_rate  department_hr  department_rnd  \
# 929                6.0                6.130017            0.0             1.0
# ...
